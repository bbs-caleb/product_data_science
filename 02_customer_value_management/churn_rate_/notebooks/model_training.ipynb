# %% [markdown]
# # Churn Prediction: model training

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 1 load data

# %%
# df = pd.read_sql(query, connection)

# df = pd.read_csv('features.csv')

# %% [markdown]
# ## 2 time-series split

# %%
# валидация по времени, не random split
train_end_date = '2022-11-01'
val_end_date = '2022-11-15'

train = df[df['day'] < train_end_date]
val = df[(df['day'] >= train_end_date) & (df['day'] < val_end_date)]
test = df[df['day'] >= val_end_date]

# %% [markdown]
# ## 3 features

# %%
feature_cols = [
    'days_offline',
    'avg_submits_14d',
    'success_rate_14d',
    'solved_total',
    'avg_submits_7d',
]

X_train = train[feature_cols]
y_train = train['target_14d']

X_val = val[feature_cols]
y_val = val['target_14d']

# %% [markdown]
# ## 4 train model

# %%
# ridge regression
model = Ridge(alpha=1.0)
model.fit(X_train, y_train)

# %% [markdown]
# ## 5 evaluating part
